# %%
# !pip install -q -U google-generativeai

# %%
from google import genai
from google.genai import types
import torch
import torch.nn as nn
import PIL.Image

# %%
client = genai.Client(api_key='AIzaSyB2dCZH_ZpNTk9v1X4HTmPq20W2eETY8mo')

# %%
class SupplyChainNet(nn.Module):
  def __init__(self):
    super(SupplyChainNet, self).__init__()
    self.fc1 = nn.Linear(2, 16)
    self.fc2 = nn.Linear(16, 3)

  def forward(self, x):
    return self.fc2(torch.relu(self.fc1(x)))

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents="Explain how to map ABC supply chain classes to PyTorch tensors.",
    config=types.GenerateContentConfig(
        system_instruction="You are a Supply Chain Data Scientist."
    )
)

# %%
print(response.text)
# Out:
# As a Supply Chain Data Scientist, mapping ABC supply chain classes to PyTorch tensors is a common task when preparing data for machine learning models. ABC classification categorizes inventory items based on their value or criticality (e.g., A-items are high-value/critical, C-items are low-value/less critical).
#
# The challenge is that ABC classes are *categorical labels* (A, B, C), while PyTorch tensors are *numerical*. You need to convert these labels into a numerical representation that PyTorch can understand and process.
#
# There are two primary methods for this:
#
# 1.  **Ordinal Encoding:** Assigning a unique integer to each class based on its inherent order.
# 2.  **One-Hot Encoding:** Creating a binary vector for each class.
#
# Let's break down how to do both, and when to choose which.
#
# ---
#
# ### Understanding ABC Classes
#
# *   **A-items:** ~10-20% of items, ~70-80% of total value/volume. High priority.
# ...
